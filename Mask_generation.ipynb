# %% [markdown]
# # Script to generate binary masks for each cell-type
# # Created by Ruchika Verma
#
# This code will create separate folder for each patient and subfolders for annotated images under each patient's folder.
#
# Each sub-folder corresponding to patient (image name) will contain 4 sub-sub-folders (Epithelial, Lymphocyte, Neutrophil and Macrophage) to save their corresponding binary-masks with value 255 for each cell-type and background 0
#
# # Input
# data_path: Specify the path of downloaded images
#
# destination_path = Specify the path to save corresponding binary masks
#
# # Output
# MoNuSAC_masks directory in the destination_path
#
# Binary masks will be saved in each sub-sub-folder
#
# Folder -> Patient name
#
# Sub-folder -> Sub-images under each patient
#
# Sub-Sub-folder -> Annotated cell-type on each sub-image

# %%
#Process whole slide images
import os
import openslide
from xml.dom import minidom
import numpy as np
import openslide
from openslide import open_slide  
from glob import glob
import cv2
import matplotlib.pyplot as plt
import scipy.io as sio
from PIL import Image
import scipy
import scipy.ndimage
from shapely.geometry import Polygon
from skimage import draw
import xml.etree.ElementTree as ET

# %%
# Read svs files from the desired path
count = 0
data_path = 'D:\MoNuSAC_annotations' #Path to read data from
destination_path = 'D:\MoNuSAC' # Path to save binary masks corresponding to xml files
os.chdir(destination_path)

try:
    os.mkdir(destination_path+'\MoNuSAC_masks')
except OSError:
    print ("Creation of the mask directory %s failed" % destination_path)
    
os.chdir(destination_path+'\MoNuSAC_masks')#Create folder named as MoNuSAC_masks
patients = [x[0] for x in os.walk(data_path)]#Total patients in the data_path
len(patients)
# Out:
# 15

# %%
for patient_loc in patients:
    patient_name = patient_loc[len(data_path)+1:]#Patient name
    print(patient_name)
    
    ## To make patient's name directory in the destination folder
    try:
        os.mkdir(patient_name)
    except OSError:
        print ("\n Creation of the patient's directory %s failed" % patient_name)
        
    ## Read sub-images of each patient in the data path        
    sub_images = glob(patient_loc+'/*.svs')
    for sub_image_loc in sub_images:
        sub_image_name = sub_image_loc[len(data_path)+len(patient_name)+1:-4]        
        print(sub_image_name)
        
        ## To make sub_image directory under the patient's folder
        sub_image = './'+patient_name+'/'+sub_image_name #Destination path
        try:
            os.mkdir(sub_image)
        except OSError:
            print ("\n Creation of the patient's directory %s failed" % sub_image)
            
        image_name = sub_image_loc
        img = openslide.OpenSlide(image_name)
                                  
        # If svs image needs to save in tif
        cv2.imwrite(sub_image_loc[:-4]+'.tif', np.array(img.read_region((0,0),0,img.level_dimensions[0])))      
   
        # Read xml file
        xml_file_name  = image_name[:-4]
        xml_file_name = xml_file_name+'.xml'
        tree = ET.parse(xml_file_name)
        root = tree.getroot()
        
        #Generate binary mask for each cell-type                         
        for k in range(len(root)):
            label = [x.attrib['Name'] for x in root[k][0]]
            label = label[0]
            
            for child in root[k]:
                for x in child:
                    r = x.tag
                    if r == 'Attribute':
                        count = count+1
                        print(count)
                        label = x.attrib['Name']
                        binary_mask = np.transpose(np.zeros((img.read_region((0,0),0,img.level_dimensions[0]).size))) 
                        print(label)
                        
                        # Create directory for each label
                        sub_path = sub_image+'/'+label
                        
                        try:
                            os.mkdir(sub_path)
                        except OSError:
                            print ("Creation of the directory %s failed" % label)
                        else:
                            print ("Successfully created the directory %s " % label) 
                                          
                        
                    if r == 'Region':
                        regions = []
                        vertices = x[1]
                        coords = np.zeros((len(vertices), 2))
                        for i, vertex in enumerate(vertices):
                            coords[i][0] = vertex.attrib['X']
                            coords[i][1] = vertex.attrib['Y']        
                        regions.append(coords)
                        poly = Polygon(regions[0])  
                        
                        vertex_row_coords = regions[0][:,0]
                        vertex_col_coords = regions[0][:,1]
                        fill_row_coords, fill_col_coords = draw.polygon(vertex_col_coords, vertex_row_coords, binary_mask.shape)
                        binary_mask[fill_row_coords, fill_col_coords] = 255
                        mask_path = sub_path+'/'+str(count)+'_mask.tif'
                        cv2.imwrite(mask_path, binary_mask)
# Out:
#  Creation of the patient's directory  failed
# TCGA-EJ-5495-01Z-00-DX1.0db6207b-4cc6-463c-8b9e-6bd6f67b7b62
# \TCGA-EJ-5495-01Z-00-DX1-1
# 1
# Epithelial
# Successfully created the directory Epithelial
# 2
# Lymphocyte
# Successfully created the directory Lymphocyte
# \TCGA-EJ-5495-01Z-00-DX1-2
# 3
# Epithelial
# Successfully created the directory Epithelial
# 4
# Lymphocyte
# Successfully created the directory Lymphocyte
# \TCGA-EJ-5495-01Z-00-DX1-3
# 5
# Epithelial
# Successfully created the directory Epithelial
# 6
# Lymphocyte
# Successfully created the directory Lymphocyte
# 7
# Neutrophil
# Successfully created the directory Neutrophil
# 8
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5495-01Z-00-DX1-4
# 9
# Epithelial
# Successfully created the directory Epithelial
# 10
# Lymphocyte
# Successfully created the directory Lymphocyte
# 11
# Neutrophil
# Successfully created the directory Neutrophil
# 12
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EJ-5505-01Z-00-DX1.8e43f020-053f-47d9-842d-4d30a776ffd2
# \TCGA-EJ-5505-01Z-00-DX1-1
# 13
# Epithelial
# Successfully created the directory Epithelial
# 14
# Lymphocyte
# Successfully created the directory Lymphocyte
# 15
# Neutrophil
# Successfully created the directory Neutrophil
# 16
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5505-01Z-00-DX1-2
# 17
# Epithelial
# Successfully created the directory Epithelial
# 18
# Lymphocyte
# Successfully created the directory Lymphocyte
# 19
# Neutrophil
# Successfully created the directory Neutrophil
# 20
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5505-01Z-00-DX1-3
# 21
# Epithelial
# Successfully created the directory Epithelial
# 22
# Lymphocyte
# Successfully created the directory Lymphocyte
# 23
# Neutrophil
# Successfully created the directory Neutrophil
# 24
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5505-01Z-00-DX1-4
# 25
# Epithelial
# Successfully created the directory Epithelial
# 26
# Lymphocyte
# Successfully created the directory Lymphocyte
# 27
# Neutrophil
# Successfully created the directory Neutrophil
# 28
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5505-01Z-00-DX1-5
# 29
# Epithelial
# Successfully created the directory Epithelial
# 30
# Lymphocyte
# Successfully created the directory Lymphocyte
# 31
# Neutrophil
# Successfully created the directory Neutrophil
# 32
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-EJ-5505-01Z-00-DX1-6
# 33
# Epithelial
# Successfully created the directory Epithelial
# 34
# Lymphocyte
# Successfully created the directory Lymphocyte
# 35
# Neutrophil
# Successfully created the directory Neutrophil
# 36
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EJ-5517-01Z-00-DX1.7df66a54-404a-4b7d-a316-4ae6383c3afd
# \TCGA-EJ-5517-01Z-00-DX1-1
# 37
# Neutrophil
# Successfully created the directory Neutrophil
# 38
# Epithelial
# Successfully created the directory Epithelial
# 39
# Lymphocyte
# Successfully created the directory Lymphocyte
# \TCGA-EJ-5517-01Z-00-DX1-2
# 40
# Neutrophil
# Successfully created the directory Neutrophil
# \TCGA-EJ-5517-01Z-00-DX1-3
# 41
# Neutrophil
# Successfully created the directory Neutrophil
# \TCGA-EJ-5517-01Z-00-DX1-4
# 42
# Epithelial
# Successfully created the directory Epithelial
# 43
# Lymphocyte
# Successfully created the directory Lymphocyte
# 44
# Description
# Successfully created the directory Description
# TCGA-G9-6342-01Z-00-DX1.5ea9bcc5-b2ce-4aef-a89d-c02eb3fd8910
# \TCGA-G9-6342-01Z-00-DX1-1
# 45
# Epithelial
# Successfully created the directory Epithelial
# 46
# Lymphocyte
# Successfully created the directory Lymphocyte
# 47
# Neutrophil
# Successfully created the directory Neutrophil
# 48
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-G9-6342-01Z-00-DX1-2
# 49
# Epithelial
# Successfully created the directory Epithelial
# 50
# Lymphocyte
# Successfully created the directory Lymphocyte
# 51
# Neutrophil
# Successfully created the directory Neutrophil
# 52
# Macrophage
# Successfully created the directory Macrophage
# TCGA-G9-6499-01Z-00-DX1.4d60a36f-fccc-44b5-b8df-360fbc704c23
# \TCGA-G9-6499-01Z-00-DX1-1
# 53
# Macrophages
# Successfully created the directory Macrophages
# \TCGA-G9-6499-01Z-00-DX1-2
# 54
# Lymphocyte
# Successfully created the directory Lymphocyte
# \TCGA-G9-6499-01Z-00-DX1-3
# 55
# Lymphocyte
# Successfully created the directory Lymphocyte
# 56
# Neutrophil
# Successfully created the directory Neutrophil
# \TCGA-G9-6499-01Z-00-DX1-4
# 57
# Epithelial
# Successfully created the directory Epithelial
# 58
# Lymphocyte
# Successfully created the directory Lymphocyte
# \TCGA-G9-6499-01Z-00-DX1-5
# 59
# Lymphocyte
# Successfully created the directory Lymphocyte
# 60
# Epithelial
# Successfully created the directory Epithelial
# TCGA-J4-A67Q-01Z-00-DX1.B5CD0AFF-2F1F-49CC-AB0E-A2972638D6DD
# \TCGA-J4-A67Q-01Z-00-DX1-1
# 61
# Epithelial
# Successfully created the directory Epithelial
# 62
# Lymphocyte
# Successfully created the directory Lymphocyte
# 63
# Neutrophil
# Successfully created the directory Neutrophil
# 64
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67Q-01Z-00-DX1-2
# 65
# Epithelial
# Successfully created the directory Epithelial
# 66
# Lymphocyte
# Successfully created the directory Lymphocyte
# 67
# Neutrophil
# Successfully created the directory Neutrophil
# 68
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67Q-01Z-00-DX1-3
# 69
# Epithelial
# Successfully created the directory Epithelial
# 70
# Lymphocyte
# Successfully created the directory Lymphocyte
# 71
# Neutrophil
# Successfully created the directory Neutrophil
# 72
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67Q-01Z-00-DX1-4
# 73
# Epithelial
# Successfully created the directory Epithelial
# 74
# Lymphocyte
# Successfully created the directory Lymphocyte
# 75
# Neutrophil
# Successfully created the directory Neutrophil
# 76
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67Q-01Z-00-DX1-5
# 77
# Epithelial
# Successfully created the directory Epithelial
# 78
# Lymphocyte
# Successfully created the directory Lymphocyte
# 79
# Neutrophil
# Successfully created the directory Neutrophil
# 80
# Macrophage
# Successfully created the directory Macrophage
# TCGA-J4-A67T-01Z-00-DX1.CF24F5B1-8583-4DEB-BDE8-45786116488E
# \TCGA-J4-A67T-01Z-00-DX1-1
# 81
# Epithelial
# Successfully created the directory Epithelial
# 82
# Lymphocyte
# Successfully created the directory Lymphocyte
# 83
# Neutrophil
# Successfully created the directory Neutrophil
# 84
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67T-01Z-00-DX1-2
# 85
# Epithelial
# Successfully created the directory Epithelial
# 86
# Lymphocyte
# Successfully created the directory Lymphocyte
# 87
# Neutrophil
# Successfully created the directory Neutrophil
# 88
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67T-01Z-00-DX1-3
# 89
# Epithelial
# Successfully created the directory Epithelial
# 90
# Lymphocyte
# Successfully created the directory Lymphocyte
# 91
# Neutrophil
# Successfully created the directory Neutrophil
# 92
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67T-01Z-00-DX1-4
# 93
# Epithelial
# Successfully created the directory Epithelial
# 94
# Lymphocyte
# Successfully created the directory Lymphocyte
# 95
# Neutrophil
# Successfully created the directory Neutrophil
# 96
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67T-01Z-00-DX1-5
# 97
# Epithelial
# Successfully created the directory Epithelial
# 98
# Lymphocyte
# Successfully created the directory Lymphocyte
# 99
# Neutrophil
# Successfully created the directory Neutrophil
# 100
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-J4-A67T-01Z-00-DX1-6
# 101
# Epithelial
# Successfully created the directory Epithelial
# 102
# Lymphocyte
# Successfully created the directory Lymphocyte
# 103
# Neutrophil
# Successfully created the directory Neutrophil
# 104
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A59X-01Z-00-DX1.8F30C2E2-BBA2-4857-B020-E548C4D7C359
# \TCGA-KK-A59X-01Z-00-DX1-1
# 105
# Epithelial
# Successfully created the directory Epithelial
# 106
# Lymphocyte
# Successfully created the directory Lymphocyte
# 107
# Neutrophil
# Successfully created the directory Neutrophil
# 108
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A59X-01Z-00-DX1-2
# 109
# Epithelial
# Successfully created the directory Epithelial
# 110
# Lymphocyte
# Successfully created the directory Lymphocyte
# 111
# Neutrophil
# Successfully created the directory Neutrophil
# 112
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A59X-01Z-00-DX1-3
# 113
# Epithelial
# Successfully created the directory Epithelial
# 114
# Lymphocyte
# Successfully created the directory Lymphocyte
# 115
# Neutrophil
# Successfully created the directory Neutrophil
# 116
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A6E0-01Z-00-DX1.F69CA949-C533-4D94-AB14-C70E2EA3B58B
# \TCGA-KK-A6E0-01Z-00-DX1-1
# 117
# Epithelial
# Successfully created the directory Epithelial
# 118
# Lymphocyte
# Successfully created the directory Lymphocyte
# 119
# Neutrophil
# Successfully created the directory Neutrophil
# 120
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A6E0-01Z-00-DX1-2
# 121
# Epithelial
# Successfully created the directory Epithelial
# 122
# Lymphocyte
# Successfully created the directory Lymphocyte
# 123
# Neutrophil
# Successfully created the directory Neutrophil
# 124
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A6E0-01Z-00-DX1-3
# 125
# Epithelial
# Successfully created the directory Epithelial
# 126
# Lymphocyte
# Successfully created the directory Lymphocyte
# 127
# Neutrophil
# Successfully created the directory Neutrophil
# 128
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A6E0-01Z-00-DX1-4
# 129
# Epithelial
# Successfully created the directory Epithelial
# 130
# Lymphocyte
# Successfully created the directory Lymphocyte
# 131
# Neutrophil
# Successfully created the directory Neutrophil
# 132
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-KK-A6E0-01Z-00-DX1-5
# 133
# Epithelial
# Successfully created the directory Epithelial
# 134
# Lymphocyte
# Successfully created the directory Lymphocyte
# 135
# Neutrophil
# Successfully created the directory Neutrophil
# 136
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A7AW-01Z-00-DX1.F8A3E0D5-AC32-4C57-8AE2-5B98790544E7
# \TCGA-KK-A7AW-01Z-00-DX1-1
# 137
# Epithelial
# Successfully created the directory Epithelial
# 138
# Lymphocyte
# Successfully created the directory Lymphocyte
# 139
# Neutrophil
# Successfully created the directory Neutrophil
# 140
# Macrophage
# Successfully created the directory Macrophage
# TCGA-V1-A8WL-01Z-00-DX1.D8496440-4A64-405B-ADC7-4F8E91BBB439
# \TCGA-V1-A8WL-01Z-00-DX1-1
# 141
# Epithelial
# Successfully created the directory Epithelial
# 142
# Lymphocyte
# Successfully created the directory Lymphocyte
# 143
# Neutrophil
# Successfully created the directory Neutrophil
# 144
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-V1-A8WL-01Z-00-DX1-2
# 145
# Epithelial
# Successfully created the directory Epithelial
# 146
# Lymphocyte
# Successfully created the directory Lymphocyte
# 147
# Neutrophil
# Successfully created the directory Neutrophil
# 148
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-V1-A8WL-01Z-00-DX1-3
# 149
# Epithelial
# Successfully created the directory Epithelial
# 150
# Lymphocyte
# Successfully created the directory Lymphocyte
# 151
# Neutrophil
# Successfully created the directory Neutrophil
# 152
# Macrophage
# Successfully created the directory Macrophage
# \TCGA-V1-A8WL-01Z-00-DX1.D8496440-4A64-405B-ADC7-4F8E91BBB439
